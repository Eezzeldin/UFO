# %%
#Run once and then comment out

#!pip install gdown
#!gdown --id 1uRgJ5MzqoGh-XYQUFAVBUGQYlLi7aMXx 
#!unzip ABSA_glove_absa.zip

# %%
import os

# Install java
! apt-get update -qq
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! java -version

# Install pyspark
! pip install --ignore-installed -q pyspark==2.4.4
! pip install --ignore-installed -q spark-nlp==2.6.3-rc1
# Out:
# openjdk version "1.8.0_275"
# OpenJDK Runtime Environment (build 1.8.0_275-8u275-b01-0ubuntu1~18.04-b01)
# OpenJDK 64-Bit Server VM (build 25.275-b01, mixed mode)

# %%
import sparknlp

spark = sparknlp.start()

# params =>> gpu=False, spark23=False (start with spark 2.3)

print("Spark NLP version", sparknlp.version())

print("Apache Spark version:", spark.version)
# Out:
# Spark NLP version 2.6.3-rc1
# Apache Spark version: 2.4.4

# %%
from sparknlp.annotator import *
from sparknlp.base import *

# %%
document = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

sentence = SentenceDetector()\
    .setInputCols(['document'])\
    .setOutputCol('sentence')

token = Tokenizer()\
    .setInputCols(['document'])\
    .setOutputCol('token')

glove_embeddings = WordEmbeddingsModel.pretrained("glove_840B_300", "xx")\
    .setInputCols(["document", "token"])\
    .setOutputCol("embeddings")
    
loaded_ner_model = NerDLModel.load("ABSA_glove_absa")\
    .setInputCols(["document", "token", "embeddings"])\
    .setOutputCol("absa")

converter = NerConverter()\
    .setInputCols(["document", "token", "absa"])\
    .setOutputCol("absa_span")

ner_prediction_pipeline = Pipeline(
    stages = [
        document,
        token,
        glove_embeddings,
        loaded_ner_model,
        converter])
# Out:
# glove_840B_300 download started this may take some time.
# Approximate size to download 2.3 GB
# [OK!]

# %%
import pandas as pd
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
path     = '/gdrive/My Drive/Colab Notebooks//'
file_name = 'text_pp3.csv'
data_file = path + file_name
data = pd.read_csv (data_file , error_bad_lines=False ,encoding = "ISO-8859-1")

# %%
def do (text,ner_prediction_pipeline,document,sentence):
    empty_data = spark.createDataFrame([['']]).toDF("text")
    prediction_model = ner_prediction_pipeline.fit(empty_data)
    sent_pipeline = Pipeline(stages = [document, sentence])
    df = spark.createDataFrame(pd.DataFrame({'text': [text]}))
    df1 = prediction_model.transform(df).toPandas()
    df2 = sent_pipeline.fit(empty_data).transform(df).toPandas()
    all_sents = df2['sentence'][0]
    sentences = []
    aspects = []
    sentiments = []
    for result in df1['absa_span'][0]:
        start, end = result['begin'], result['end']
        for sent in all_sents:
            if sent['begin'] <= start and sent['end'] >= end:
                sentences.append(sent['result'])
        aspects.append(result['result'])
        sentiment = "positive" if result['metadata']['entity'] == "POS" else "negative"
        sentiments.append(sentiment)
    final_result = pd.DataFrame.from_dict({"sentence": sentences, "aspect": aspects, "sentiment": sentiments})
    #print (final_result)
    #del glove_embeddings
    return final_result

# %%
path     = '/gdrive/My Drive/Colab Notebooks//'
file_name = 'text_pp3_annotated.csv'
data_file = path + file_name
initial_df = pd.DataFrame (columns = ['sentence' , 'aspect' , 'sentiment'])
counter    = 0 
for description in data ['text'].dropna().values[55000:60000]:
     try:
      #print (description)
      counter = counter  + 1
      print (counter , "out of" , data.shape [0] )
      combo_df = do (description,ner_prediction_pipeline,document,sentence)
      print (combo_df)
      combo_df.to_csv (data_file,mode= 'a' ,header = False)
      #initial_df = initial_df.append ( combo_df)
      del combo_df
     except Exception as e:
       #print ("**" * 100) 
       print("Error Detected",e)
       continue
# Out:
# Streaming output truncated to the last 5000 lines.
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1220 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'http://t.co/wZ1IxNKCwe happened to all see...  lights  negative
# 1  [" 'http://t.co/wZ1IxNKCwe happened to all see...  lights  negative
# 1221 out of 92862
#                                             sentence           aspect sentiment
# 0  [' making no sound.I was watching the firework...  upstairs window  positive
# 1  I thought they may have been lanterns', ' but ...     lanterns', '  negative
# 1222 out of 92862
#                                             sentence  aspect sentiment
# 0  [' my sister-in-law', ' and myself. We were at...  window  negative
# 1  [' my sister-in-law', ' and myself. We were at...  lights  negative
# 2  [' my sister-in-law', ' and myself. We were at...  lights  negative
# 3  The lights appeared to move independently of e...  lights  negative
# 1223 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1224 out of 92862
#                                             sentence       aspect sentiment
# 0  [' "Orange orbs in triangle formaton spotted s...  Orange orbs  positive
# 1225 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Triangular shaped object with orange glow ...  ...  positive
# 1  [" 'Triangular shaped object with orange glow ...  ...  positive
# 2  A couple minutes after the fireworks stopped m...  ...  positive
#
# [3 rows x 3 columns]
# 1226 out of 92862
#                                             sentence  aspect sentiment
# 0  [" '15+ Lights seen on the Wasatch mountain ra...  lights  negative
# 1  I called a friend to ask him if he could see t...  lights  negative
# 1227 out of 92862
#                                             sentence  aspect sentiment
# 0  [' the lights would go out to become discs.12:...  lights  negative
# 1  [' the lights would go out to become discs.12:...  lights  negative
# 2  [' the lights would go out to become discs.12:...  lights  negative
# 3  The lights disappeared from the right as if go...  lights  negative
# 1228 out of 92862
#                                             sentence     aspect sentiment
# 0  [" 'Three glowing red lights moving slowly ove...     lights  positive
# 1  I ran inside to wake up my husband', ' and he ...     lights  negative
# 2  That could be', ' but if so they were unlike a...  person.If  negative
# 1229 out of 92862
#                                             sentence      aspect sentiment
# 0  [' Chicago', ' ILWere walking back to our vehi...  helicopter  negative
# 1230 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'saw  a red light pass over usMyself and 3 ...  ...  positive
#
# [1 rows x 3 columns]
# 1231 out of 92862
#                                             sentence    aspect sentiment
# 0  Sky was overcast but visibility was good.I wat...  aircraft  negative
# 1232 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1233 out of 92862
#                                             sentence  aspect sentiment
# 0  The lights slowly faded away after approximate...  lights  negative
# 1234 out of 92862
#                                             sentence    aspect sentiment
# 0  First sighted heading west â began as a tria...    lights  negative
# 1  Next we noticed some lights were following beh...    lights  negative
# 2  The lights (at least 20', ' probably more) the...    lights  negative
# 3  The catepillar-like loose', " linear formation...    lights  negative
# 4                                no aircraft sounds.  aircraft  negative
# 1235 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1236 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1237 out of 92862
#                                        sentence  aspect sentiment
# 0  There were no blinking lights or spotlights;  lights  negative
# 1238 out of 92862
#                                             sentence  aspect sentiment
# 0  They were spinning like a basket ball would be...  basket  negative
# 1239 out of 92862
#                                             sentence  ... sentiment
# 0  [" '7 bright", ' reddish-orange orbs seen flyi...  ...  positive
# 1  [" '7 bright", ' reddish-orange orbs seen flyi...  ...  negative
#
# [2 rows x 3 columns]
# 1240 out of 92862
#                                             sentence       aspect sentiment
# 0  [' GAShortly after midnight', ' we observed th...       lights  positive
# 1  [' GAShortly after midnight', ' we observed th...  helicopters  negative
# 2  [' GAShortly after midnight', ' we observed th...       lights  negative
# 3  They also didn't dissipate or lose altitude", ...       lights  negative
# 1241 out of 92862
#                                             sentence      aspect sentiment
# 0  [' "big amber oval seen traveling north over P...        fire  positive
# 1  the light at first looked like a helicopter bu...    aircraft  negative
# 2  (obvious) helicopter flew from the north to th...  helicopter  negative
# 1242 out of 92862
#                                             sentence  aspect sentiment
# 0  5 lights by southern mountains outside Anchora...  lights  positive
# 1243 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1244 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Four bright ornge lights flying in a wave ...  lights  negative
# 1245 out of 92862
#                                             sentence           aspect sentiment
# 0  [' "Reddish orange silent orb on new years eve...  "Reddish orange  positive
# 1246 out of 92862
#                                             sentence  ... sentiment
# 0  [' "Three orange orbs over Eastgate OhioAt pre...  ...  positive
# 1  The front door was left wide open with my wife...  ...  positive
# 2  I ran outside to find three brilliantly glowin...  ...  positive
# 3  They were not filled with LED lights", ' the l...  ...  negative
# 4  We have also both seen brilliant blue lights d...  ...  positive
#
# [5 rows x 3 columns]
# 1247 out of 92862
#                                             sentence    aspect sentiment
# 0      The aircraft was unlike anything we observed.  aircraft  negative
# 1  The crafts were not easy to observe and emitte...    crafts  negative
# 2  The craft initially came very close to us", ' ...    planes  negative
# 1248 out of 92862
#                                             sentence      aspect sentiment
# 0  nge sphere seen by three people in South Louis...  nge sphere  positive
# 1249 out of 92862
#                                             sentence   aspect sentiment
# 0  when the thang was almost over our heads it go...  13th.']  negative
# 1250 out of 92862
#                                             sentence          aspect sentiment
# 0  [' "Weird orange/red balloon lights on New Yea...  balloon lights  positive
# 1  Looked to me to be balloons with some kind of ...             air  negative
# 1251 out of 92862
#                                             sentence        aspect sentiment
# 0  [' "Orange Balls of Light/Shooting star that w...  Orange Balls  positive
# 1  [' "Orange Balls of Light/Shooting star that w...      aircraft  positive
# 1252 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1253 out of 92862
#                                             sentence       aspect sentiment
# 0  [" 'Orange orbs seen in Anderson", ' Ca.2-7-13...  Orange orbs  positive
# 1  I canât stop wondering what it was that I an...     aircraft  negative
# 1254 out of 92862
#                                             sentence         aspect sentiment
# 0  [' \'2012 newyears just before the clock strik...       ufo flys  positive
# 1  When I first saw this video I was skeptical bu...  camera angles  positive
# 1255 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Moving lights that changed colors and sped...  lights  negative
# 1256 out of 92862
#                                             sentence  aspect sentiment
# 0  [' Az New Years 2012approximatley at 11:55 to ...  lights  negative
# 1  [' Az New Years 2012approximatley at 11:55 to ...  lights  negative
# 1257 out of 92862
#                                             sentence    aspect sentiment
# 0  No strobe on the craft was seen as you would s...  aircraft  negative
# 1  This craft appeared to look slow but again bec...     craft  negative
# 2  I watched the sky for thirty more mins and did...  aircraft  negative
# 1258 out of 92862
#                                             sentence aspect sentiment
# 0  Suddenly", ' it stopped.  Then the fireworks s...   ball  positive
# 1259 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Two orange bright circular objects kept go...  " 'Two  negative
# 1260 out of 92862
#                                             sentence       aspect sentiment
# 0  [' "8-10 orange UFO\'s sited New Years Eve', '...       lights  negative
# 1   There were many small planes flying in the area.       planes  negative
# 2  I am sure to see the fireworks', ' and a coupl...  helicopters  positive
# 3  I am sure to see the fireworks', ' and a coupl...       lights  negative
# 1261 out of 92862
#                                             sentence aspect sentiment
# 0  ['hovered appprox 15 seconds', ' rapidly disap...   iris  positive
# 1262 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "Orange-Red spherical oblong shaped craft f...  driver  negative
# 1  The glowing orange red craft were flying in li...   craft  negative
# 1263 out of 92862
#                                             sentence         aspect sentiment
# 0  [" '15 disc shaped", ' silent', ' slow moving ...  lighted craft  positive
# 1264 out of 92862
#                                             sentence  aspect sentiment
# 0  Two additional", ' smaller lights rotated arou...  lights  negative
# 1265 out of 92862
#                                             sentence  ... sentiment
# 0  [' "2 bright orange irregular lights moving sl...  ...  negative
# 1  The lights were orange in color and brighter t...  ...  negative
# 2  The lights were orange in color and brighter t...  ...  negative
# 3  There was no discernible outline of a physical...  ...  negative
#
# [4 rows x 3 columns]
# 1266 out of 92862
#                                             sentence    aspect sentiment
# 0  ["VT area New Year's EveI was going north on i...  area New  positive
# 1267 out of 92862
#                                             sentence aspect sentiment
# 0  [" NMShape: TeardropDuration:10 seconds'", " '...  green  positive
# 1268 out of 92862
#                                             sentence  ... sentiment
# 0  [' "Bright Orange Flame like Orbs in the sky o...  ...  positive
#
# [1 rows x 3 columns]
# 1269 out of 92862
#                                             sentence         aspect sentiment
# 0  [' "Orange Lights - 13 in formation over Lake ...  Orange Lights  positive
# 1  [' "Orange Lights - 13 in formation over Lake ...         lights  negative
# 2  [' "Orange Lights - 13 in formation over Lake ...         lights  positive
# 3  You can see the moon and the reflection of the...         lights  positive
# 1270 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Witnessed 4 orange lights", ' 3 equidistan...  lights  negative
# 1     They couldn\\'t have been lights from a plane.  lights  negative
# 2  The lights seemed to be traveling slowly", ' a...  lights  negative
# 3  The lights seemed to be traveling slowly", ' a...  lights  negative
# 4  The lights seemed to be traveling slowly", ' a...  lights  negative
# 1271 out of 92862
#                                             sentence  ... sentiment
# 0  [' "Bright Orange Sphere wobbling while Bright...  ...  positive
#
# [1 rows x 3 columns]
# 1272 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Bright orange light moving horizontally ac...  ...  positive
#
# [1 rows x 3 columns]
# 1273 out of 92862
#                                             sentence  aspect sentiment
# 0  There were no blinking lights as are typical t...  lights  negative
# 1274 out of 92862
#                                             sentence aspect sentiment
# 0  [' just like small stars', ' doing some format...     ['  negative
# 1  About 3 groups of 4 'stars'.   Sometimes each ...   line  negative
# 1275 out of 92862
#                                             sentence        aspect sentiment
# 0  [" 'Big Black Rectangle over GeorgiaI was flyi...     Attendant  negative
# 1  I was pass riding", ' sitting on the right sid...      aircraft  negative
# 2  I was pass riding", ' sitting on the right sid...  cockpit crew  negative
# 3  I was pass riding", ' sitting on the right sid...      aircraft  negative
# 4                              It only had 3 lights;        lights  negative
# 5  one white light in front which which covered t...     aircrafts  negative
# 6  one white light in front which which covered t...       cockpit  negative
# 1276 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Green light/sphere seen in Prescott/Presco...  ...  positive
#
# [1 rows x 3 columns]
# 1277 out of 92862
#                                             sentence    aspect sentiment
# 0  These lights werenât blinking so we knew it ...    lights  negative
# 1  These lights werenât blinking so we knew it ...  aircraft  negative
# 1278 out of 92862
#                                             sentence    aspect sentiment
# 0  It was non-comparable to any aircraft and must...  aircraft  positive
# 1279 out of 92862
#                                             sentence         aspect sentiment
# 0  [" 'Three lights were seen", ' forming a trian...  'Three lights  negative
# 1  [" 'Three lights were seen", ' forming a trian...  orange lights  positive
# 2  [" 'Three lights were seen", ' forming a trian...         lights  negative
# 1280 out of 92862
#                                sentence               aspect sentiment
# 0  provides little contact information.  contact information  positive
# 1281 out of 92862
#                                             sentence         aspect sentiment
# 0  We did not hear any sound and we could not see...         lights  negative
# 1  We did not hear any sound and we could not see...  space station  positive
# 1282 out of 92862
#                                             sentence    aspect sentiment
# 0  [' "oval object', ' fast moving with a light g...  lighting  negative
# 1  It was about the size of my thumb nail and had...      tail  negative
# 1283 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1284 out of 92862
#                                             sentence         aspect sentiment
# 0  The airport is approximately 10 airline miles ...  passenger jet  negative
# 1285 out of 92862
#                                          sentence  ... sentiment
# 0  It was going about the speed of a small plane.  ...  negative
# 1            provides little contact information.  ...  positive
#
# [2 rows x 3 columns]
# 1286 out of 92862
#                                             sentence      aspect sentiment
# 0  Then when it was fully in the front windshied'...  red lights  negative
# 1  the vision was about two times the size of a f...      vision  negative
# 1287 out of 92862
#                                             sentence  aspect sentiment
# 0  [' 2011', ' my mother called my attention to s...  lights  positive
# 1  [' 2011', ' my mother called my attention to s...  lights  negative
# 2  [' 2011', ' my mother called my attention to s...  lights  negative
# 1288 out of 92862
#                                             sentence  ... sentiment
# 0  I believe Less in the American media than I do...  ...  positive
# 1  For starters', ' what I saw was brilliant and ...  ...  positive
# 2     Definitely not space junkâ¦This was not that.  ...  negative
#
# [3 rows x 3 columns]
# 1289 out of 92862
#                                             sentence  ... sentiment
# 0  As soon as I looked the light was a very beaut...  ...  positive
#
# [1 rows x 3 columns]
# 1290 out of 92862
#                                             sentence      aspect sentiment
# 0  [" 'A large green ball of light with a yellow ...  white tail  negative
# 1291 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Blue Green GlowBlue Green color - bright g...  ...  positive
#
# [1 rows x 3 columns]
# 1292 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1293 out of 92862
#                                             sentence  ... sentiment
# 0  We were sitting watching TV facing two large s...  ...  positive
#
# [1 rows x 3 columns]
# 1294 out of 92862
#                                             sentence     aspect sentiment
# 0  They were easily seen and moving faster than a...  air craft  negative
# 1  We watched five of them fly over ( almost dire...     lights  negative
# 1295 out of 92862
#                                             sentence          aspect sentiment
# 0  [" 'My husband and I were driving back from di...  circular craft  negative
# 1  We both realized', ' simultaneously', ' that i...      blue light  negative
# 1296 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1297 out of 92862
#                                             sentence      aspect sentiment
# 0  I decided to call 911 and told the dispatcher ...  dispatcher  negative
# 1298 out of 92862
#                                             sentence      aspect sentiment
# 0  Definitely was not an airplane or a helicopter...  helicopter  negative
# 1  Definitely was not an airplane or a helicopter...   satellite  negative
# 1299 out of 92862
#                                             sentence        aspect sentiment
# 0  [' SC', ' a bright orange light was seen movin...  orange light  positive
# 1300 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Fireball descends and Pops over KenoshaI w...  ...  positive
#
# [1 rows x 3 columns]
# 1301 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Two large orange colored lights over the A...  lights  negative
# 1  As I pulled my car up to the stop sign at the ...  lights  negative
# 2  As I pulled my car up to the stop sign at the ...  lights  negative
# 3  As I pulled my car up to the stop sign at the ...  lights  negative
# 1302 out of 92862
#                                             sentence aspect sentiment
# 0  It also appeared that the bright lights extend...   rear  negative
# 1303 out of 92862
#                                             sentence         aspect sentiment
# 0  [' "Bright orange object in the northern sky m...  Bright orange  positive
# 1304 out of 92862
#                                        sentence    aspect sentiment
# 0  The lights did not blink like most aircraft;    lights  negative
# 1  The lights did not blink like most aircraft;  aircraft  negative
# 1305 out of 92862
#                                             sentence  ... sentiment
# 0  [' "Strobe-like blue', 'white', ' green', ' an...  ...  positive
# 1  The lights appear to be strobe-like", ' altern...  ...  negative
# 2  We have viewed the objects with binoculars but...  ...  positive
#
# [3 rows x 3 columns]
# 1306 out of 92862
#                                             sentence  ... sentiment
# 0  This stood out as different', ' as was not fla...  ...  negative
# 1  This stood out as different', ' as was not fla...  ...  negative
#
# [2 rows x 3 columns]
# 1307 out of 92862
#                                             sentence   aspect sentiment
# 0  It was already very dark outside   I noticed s...   lights  negative
# 1  I then realized there were no stars as it was ...   lights  negative
# 2  Then I noticed one that was over land moving w...  quality  negative
# 1308 out of 92862
#                                             sentence          aspect sentiment
# 0  Right as I was joking that the lights must've ...  lights must've  negative
# 1  The lights continued their dance in the sky th...          lights  negative
# 1309 out of 92862
# Error Detected arrays must all be same length
# 1310 out of 92862
#                                             sentence   aspect sentiment
# 0  light appeared round in shape and remained equ...  path.it  negative
# 1311 out of 92862
#                                             sentence          aspect sentiment
# 0  [" '6 orange lights south of marysville", ' Wa...          lights  positive
# 1  [" '6 orange lights south of marysville", ' Wa...  colored lights  positive
# 1312 out of 92862
#                                             sentence aspect sentiment
# 0  The nite was a crystal clear full moon no clou...   view  positive
# 1313 out of 92862
#                                             sentence      aspect sentiment
# 0  I rolled down my window and turned off the ste...  helicopter  negative
# 1314 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1315 out of 92862
#                                             sentence  aspect sentiment
# 0  Anyone have any ideas yet what these lights ar...  lights  negative
# 1316 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1317 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "5 lights seen to the north of Gavin\'s Poi...  lights  negative
# 1  group of 3 joined by 2 additional55 year old c...  lights  negative
# 2  group of 3 joined by 2 additional55 year old c...  lights  negative
# 1318 out of 92862
#                                             sentence     aspect sentiment
# 0  The light really caught the witness's attentio...     lights  negative
# 1                   rest star (Deneb', ' in Cygnus).     Cygnus  negative
# 2  As they searched", ' the two observers spotted...  Air Force  negative
# 3  As they searched", ' the two observers spotted...   aircraft  negative
# 1319 out of 92862
#                                             sentence aspect sentiment
# 0  I was out on the front porch (facing south)smo...  front  negative
# 1  From what I recall', ' from center to outward'...  cabin  negative
# 1320 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Red-Orange fireball passing over Orlando o...  ...  positive
#
# [1 rows x 3 columns]
# 1321 out of 92862
#                                             sentence      aspect sentiment
# 0  These objects would be very visible and than s...  atmosphere  positive
# 1322 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "4 low hovering changing lights in the skyW...  lights  negative
# 1  The first pair was a set of red lights closely...  lights  negative
# 1323 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1324 out of 92862
#                                             sentence        aspect sentiment
# 0  [" 'little triangles", ' and one big one with ...  white lights  negative
# 1325 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'multiple triangular aircraft", ' white red...  ...  negative
# 1  [" 'multiple triangular aircraft", ' white red...  ...  positive
# 2  [" 'multiple triangular aircraft", ' white red...  ...  positive
# 3  [" 'multiple triangular aircraft", ' white red...  ...  negative
# 4  [" 'multiple triangular aircraft", ' white red...  ...  negative
# 5  lights on underside appear to be very "human" ...  ...  negative
# 6  appx height of craft flying -2500 ft above gro...  ...  negative
# 7  appx height of craft flying -2500 ft above gro...  ...  negative
#
# [8 rows x 3 columns]
# 1326 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1327 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'i stand in my yard 6days ago and what i th...  ...  positive
# 1  [" 'i stand in my yard 6days ago and what i th...  ...  positive
# 2  [" 'i stand in my yard 6days ago and what i th...  ...  negative
# 3  [" 'i stand in my yard 6days ago and what i th...  ...  negative
#
# [4 rows x 3 columns]
# 1328 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1329 out of 92862
#                                             sentence          aspect sentiment
# 0  Having a small camera the videos and one of th...  shaky.The orbs  negative
# 1330 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1331 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1332 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Green light crosses sky at very fast pace....  ...  positive
#
# [1 rows x 3 columns]
# 1333 out of 92862
#                                             sentence  ... sentiment
# 0  It is oriented by finding the Big Dipper and t...  ...  positive
# 1  The recording of video/audio picks up a hummin...  ...  negative
# 2  Still photos are grainy and show blurring of w...  ...  negative
# 3  There were 18 completely different objects on ...  ...  negative
#
# [4 rows x 3 columns]
# 1334 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Bright golden light seen twice on the same...  ...  positive
# 1  Both on the same road in the exact same area.T...  ...  negative
#
# [2 rows x 3 columns]
# 1335 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Moving groups of lightsMy wife and I were ...  lights  negative
# 1  The lights were all of the same intensity and ...  lights  negative
# 2  The lights were all of the same intensity and ...  lights  negative
# 3  The lights were all of the same intensity and ...  lights  negative
# 4  ecame hidden behind a building in front of us'...  lights  negative
# 5  ecame hidden behind a building in front of us'...  lights  negative
# 6  ecame hidden behind a building in front of us'...  lights  negative
# 7  ecame hidden behind a building in front of us'...  lights  negative
# 8  ecame hidden behind a building in front of us'...  lights  negative
# 9  ecame hidden behind a building in front of us'...  lights  negative
# 1336 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1337 out of 92862
#                                             sentence  aspect sentiment
# 0  they were orange', ' round and in the formatio...  lights  negative
# 1  I bet you'll see them too- Im not saying they ...  aliens  negative
# 1338 out of 92862
#                                             sentence    aspect sentiment
# 0  [" 'Triangle shaped aircraft with a light at e...  aircraft  negative
# 1339 out of 92862
#                                             sentence  ... sentiment
# 0  I followed it as far as I could into the horiz...  ...  negative
#
# [1 rows x 3 columns]
# 1340 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1341 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Ball of lights very far out in the AM sky ...  lights  negative
# 1342 out of 92862
#                                             sentence      aspect sentiment
# 0  After it disappeared", ' for about 15 minutes ...  helicopter  negative
# 1343 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "four orange light formation moving slowly ...  lights  positive
# 1  When I pulled the car over the lights had all ...  lights  negative
# 1344 out of 92862
#                                             sentence   aspect sentiment
# 0  I had a cashier from the Station with me and s...  cashier  negative
# 1  I talked to a police officer', ' he was mad be...  officer  negative
# 2  I talked to a police officer', ' he was mad be...   patrol  positive
# 1345 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1346 out of 92862
#                                              sentence          aspect sentiment
# 0   [" 'Four glowing orange orbs float over the ci...           'Four  negative
# 1   I am not saying the lights caused the dogs to ...          lights  negative
# 2   Second', ' not a helicopter or plane or star o...       roof eave  negative
# 3   Once outside I could see the huge clear open s...          lights  positive
# 4                                     The lights wer!          lights  negative
# 5   Which is not that high as the mountain is bare...        mountain  negative
# 6   The line of lights appeared as if it was aroun...  line of lights  negative
# 7        I stared at the lights trying to understand.          lights  negative
# 8   I am assuming they were spheres', '  because i...          lights  negative
# 9   He did not seem to care", ' although he did as...          lights  negative
# 10  The video shows exactly what I saw except ther...          lights  positive
# 1347 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Several young people witness a cluster of ...  lights  positive
# 1  [" 'Several young people witness a cluster of ...  lights  positive
# 1348 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Four family members witnessed some 14-18 b...  ...  positive
# 1  I said', " oh it\\'s probably just a helicopte...  ...  negative
# 2  I said', " oh it\\'s probably just a helicopte...  ...  negative
# 3  My father (68) and myself (40) have lived on t...  ...  negative
# 4  My father (68) and myself (40) have lived on t...  ...  negative
#
# [5 rows x 3 columns]
# 1349 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1350 out of 92862
#                                             sentence          aspect sentiment
# 0  om underneath I flipped up my rearview to see ...        rearview  negative
# 1  I asked her again because this is a very surre...           manta  negative
# 2  I wondered if it wasnât a military craft as ...  military craft  positive
# 3  I tried to snap a pic but all I got was the ro...        roofline  negative
# 1351 out of 92862
#                                             sentence     aspect sentiment
# 0  [" 'Flying Saucer PhotoI took this picture on ...  passenger  negative
# 1  [" 'Flying Saucer PhotoI took this picture on ...  passenger  negative
# 1352 out of 92862
#                                             sentence  ... sentiment
# 0  ['a between Holister and San Juan heading east...  ...  negative
# 1  This indecent caused traffic to stop on a gree...  ...  negative
# 2  This indecent caused traffic to stop on a gree...  ...  negative
#
# [3 rows x 3 columns]
# 1353 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1354 out of 92862
#                          sentence aspect sentiment
# 0  the cats were hiding upstairs.   cats  negative
# 1355 out of 92862
#                                             sentence   aspect sentiment
# 0  [" 'lights hovering in sky over Security", '  ...  'lights  negative
# 1356 out of 92862
#                                             sentence aspect sentiment
# 0  [' CAI was going home from the gym', " I stopp...     ['  negative
# 1357 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1358 out of 92862
#                                             sentence  aspect sentiment
# 0  It was triangular and approximately 10 meters ...  lights  negative
# 1359 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1360 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Two orange globes rising straight up in th...  ...  positive
#
# [1 rows x 3 columns]
# 1361 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1362 out of 92862
#                                             sentence  ... sentiment
# 0  [' "NASA has photos of an object in space movi...  ...  negative
# 1  Many articles have been filed about this event...  ...  positive
#
# [2 rows x 3 columns]
# 1363 out of 92862
#                                             sentence         aspect sentiment
# 0  [' "Big Iso-triangular craft 3 bright white li...   white lights  positive
# 1  [' "Big Iso-triangular craft 3 bright white li...   white lights  positive
# 2  A small private plane off in the distance conf...  private plane  negative
# 3  A small private plane off in the distance conf...   white lights  positive
# 4  A small private plane off in the distance conf...         lights  positive
# 5  d/Southwest Airport and have for most of my li...       aircraft  positive
# 1364 out of 92862
#                                             sentence  aspect sentiment
# 0  They were about a 1/2 mile away', ' but the li...  lights  negative
# 1365 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1366 out of 92862
#                                             sentence          aspect sentiment
# 0  [" 'Four dimly lit triangular objects whistle ...          lights  negative
# 1  [" 'Four dimly lit triangular objects whistle ...        aircraft  negative
# 2  imperfect and changing', ' but they were movin...  F117 Nighthawk  positive
# 1367 out of 92862
# Error Detected arrays must all be same length
# 1368 out of 92862
#                                             sentence  ... sentiment
# 0  [" '4 red/orange lights moving towards the nex...  ...  negative
# 1  [" '4 red/orange lights moving towards the nex...  ...  negative
#
# [2 rows x 3 columns]
# 1369 out of 92862
#                                             sentence          aspect sentiment
# 0  [" 'While walking my dog", '  I noticed severa...          lights  positive
# 1  I positioned myself to make sure I wasnt just ...  ambient lights  negative
# 2  I positioned myself to make sure I wasnt just ...          lights  negative
# 1370 out of 92862
#                                             sentence     aspect sentiment
# 0  [' "bright flashing red light moving south in ...  cigerette  negative
# 1371 out of 92862
#                                             sentence    aspect sentiment
# 0  This triggered my attention', ' and I seemed t...    lights  negative
# 1  The corners of the object were illuminating a ...  lighting  negative
# 1372 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1373 out of 92862
#                                             sentence    aspect sentiment
# 0  [' there was no noise what so ever and that ma...  aircraft  negative
# 1374 out of 92862
#                                             sentence aspect sentiment
# 0  [" 'I had stepped outside and noticed in the s...   [" '  negative
# 1375 out of 92862
#                                             sentence      aspect sentiment
# 0  [" '3 orange orbs or fireballs fly in formatio...        orbs  positive
# 1  [" '3 orange orbs or fireballs fly in formatio...  helicopter  negative
# 2  lights on them', ' and just seemed to float al...  helicopter  negative
# 3  lights on them', ' and just seemed to float al...      lights  negative
# 4  lights on them', ' and just seemed to float al...    aircraft  negative
# 1376 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Multi Colored /Shape Shifting Bright light...  ...  positive
# 1  It than began to change shapes and luminate se...  ...  positive
#
# [2 rows x 3 columns]
# 1377 out of 92862
#                                             sentence      aspect sentiment
# 0  [" 'big red lights flying lowI went outside to...  red lights  negative
# 1  I saw red lights that was very bright and was ...  red lights  negative
# 2  And there was no sound from this object either...    aircraft  negative
# 1378 out of 92862
#                                             sentence        aspect sentiment
# 0  [" happen'", ' "Definite ufo sighting', " repe...  ufo sighting  positive
# 1379 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Bright Orange Orbs flying silent over Port...  ...  positive
#
# [1 rows x 3 columns]
# 1380 out of 92862
#                                             sentence  ... sentiment
# 0  [' "Four orange lightsThere were 2 orange fire...  ...  positive
# 1  The lights didn't lose intensity", ' but did a...  ...  negative
#
# [2 rows x 3 columns]
# 1381 out of 92862
#                                             sentence  ... sentiment
# 0  [' "About 10:15pm', ' December 25th', ' I witn...  ...  positive
# 1  [' "About 10:15pm', ' December 25th', ' I witn...  ...  negative
# 2  [' "About 10:15pm', ' December 25th', ' I witn...  ...  negative
# 3  Then 5 lights appeared on both sides of the cr...  ...  negative
#
# [4 rows x 3 columns]
# 1382 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "3 yellowish lights forming a triangle with...  lights  negative
# 1  This is when I really got a feel for the size ...  lights  negative
# 1383 out of 92862
#                                             sentence       aspect sentiment
# 0  I myself live on the lake near our current loc...  helicopters  negative
# 1  I myself live on the lake near our current loc...       planes  negative
# 2  but as I said that\'s probably what it is a co...     red orbs  positive
# 1384 out of 92862
#                                             sentence  aspect sentiment
# 0  [" '3 red dots", ' form from a triangle into a...  UFO!']  positive
# 1385 out of 92862
#                                             sentence  ... sentiment
# 0  This was definitely some sort of lighted  air ...  ...  negative
#
# [1 rows x 3 columns]
# 1386 out of 92862
# Error Detected arrays must all be same length
# 1387 out of 92862
#                                             sentence    aspect sentiment
# 0  [" 'There is an object in the sky that we have...  aircraft  negative
# 1  The object appears to be a line that is flashi...      line  negative
# 1388 out of 92862
#                                             sentence           aspect sentiment
# 0  [" 'I saw a large fireball pass over my house ...  upstairs window  positive
# 1  (estimate)  The object was a fairly large glow...  orange fireball  positive
# 2    ---the fire was from three to ten feet in size.             fire  negative
# 1389 out of 92862
#                                             sentence    aspect sentiment
# 0  [" 'Orange ball in the night skyAt 2100 on Dec...    lights  negative
# 1  [" 'Orange ball in the night skyAt 2100 on Dec...  aircraft  negative
# 1390 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Very Large Triangle shaped object with mul...  lights  positive
# 1  I ran to get my wife and kid they saw the ligh...  lights  negative
# 1391 out of 92862
#                                             sentence    aspect sentiment
# 0  I noticed what I thought was an aircraft to th...  aircraft  negative
# 1  After about 8 - 10 minutes they had disappeare...  aircraft  negative
# 2  After about 8 - 10 minutes they had disappeare...      crew  negative
# 3  10.  At one air show', ' a group of old timers...  aircraft  negative
# 4  I\\'ve met those that know more about aircraft...  aircraft  negative
# 1392 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Very bright circular object hovering over ...  ...  positive
# 1  [" 'Very bright circular object hovering over ...  ...  positive
#
# [2 rows x 3 columns]
# 1393 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'More than 30 orange lights in Massachusett...  lights  positive
# 1  [" 'More than 30 orange lights in Massachusett...  lights  positive
# 2  At one point the observers counted approximate...  lights  negative
# 1394 out of 92862
#                                             sentence          aspect sentiment
# 0  [" 'Triangle fire-like ball over BurlingtonWe ...  fire-like ball  positive
# 1  [" 'Triangle fire-like ball over BurlingtonWe ...    BurlingtonWe  positive
# 1395 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Four Yellow/ golden lights alligned perfec...  ...  negative
# 1  All the lights were not moving except for one ...  ...  negative
#
# [2 rows x 3 columns]
# 1396 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Bright orange triangle shaped lights over ...  ...  positive
# 1  [" 'Bright orange triangle shaped lights over ...  ...  positive
#
# [2 rows x 3 columns]
# 1397 out of 92862
#                                             sentence  ... sentiment
# 0  [" '7 orange orbs flew across the sky one at a...  ...  negative
# 1  It took the exact same path as the first orb',...  ...  negative
#
# [2 rows x 3 columns]
# 1398 out of 92862
#                                             sentence  ... sentiment
# 0  [' "Bright stationary light above Oquirrh moun...  ...  positive
# 1  The light was still visible by the time we arr...  ...  negative
#
# [2 rows x 3 columns]
# 1399 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'orange fiery ball in the skyWhen we first ...  ...  positive
#
# [1 rows x 3 columns]
# 1400 out of 92862
#                                             sentence           aspect sentiment
# 0  I turn to look what they are pointing at and t...  circular lights  negative
# 1401 out of 92862
#                                             sentence     aspect sentiment
# 0  [" 'LARGE BRIGHT ORANGE OBJECT MOVING FROM THE...  UNUSUAL']  positive
# 1402 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Bright red light with yellow/orange lights...  ...  positive
# 1  The object was a bright glowing red light with...  ...  negative
#
# [2 rows x 3 columns]
# 1403 out of 92862
#                                             sentence          aspect sentiment
# 0              The two red lights were side by side.  two red lights  negative
# 1  As it did', ' it slowly faded away.  The other...      red lights  negative
# 1404 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1405 out of 92862
#                                             sentence  aspect sentiment
# 0  As I looked again for the red light it was als...  lights  negative
# 1406 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1407 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Red Horizontal Lights in the SkyFirst orb ...  ...  positive
#
# [1 rows x 3 columns]
# 1408 out of 92862
#                                             sentence  aspect sentiment
# 0  To the left of the car a huge space ship hover...   space  negative
# 1  It was a metalic with lights in front and stor...  lights  negative
# 1409 out of 92862
#                                             sentence aspect sentiment
# 0  The tail was the width of the light at the beg...   tail  negative
# 1410 out of 92862
#                                             sentence   aspect sentiment
# 0  \\xa0 Lights appeared to float and move\\xa0in...   Lights  negative
# 1  \\xa0Each of the 3 remaining lights disappeare...   lights  negative
# 2  \\xa0At 1:15am I drove out to the Airport and ...  Officer  negative
# 3  \\xa0Neither had seen the lights having been i...   lights  negative
# 1411 out of 92862
#                                             sentence      aspect sentiment
# 0  When I pulled up my street on my way home I no...       Norad  positive
# 1  At first I thought it might be a helicopter or...  helicopter  negative
# 1412 out of 92862
#                                             sentence  ... sentiment
# 0  Then a helicopter which appeared to be a milit...  ...  negative
# 1  ake off when a helicopter came near seemed str...  ...  negative
#
# [2 rows x 3 columns]
# 1413 out of 92862
#                                             sentence    aspect sentiment
# 0  [" 'I saw  what looked like an aircraft at first.  aircraft  negative
# 1  It was flying east to west", ' slowly.  As it ...    lights  negative
# 2  It was flying east to west", ' slowly.  As it ...    lights  negative
# 1414 out of 92862
#                                             sentence aspect sentiment
# 0  I seemed to cover quite a bit of area in littl...   area  negative
# 1415 out of 92862
#                                      sentence    aspect sentiment
# 0  It looked like it was an aircraft on fire.  aircraft  negative
# 1416 out of 92862
#                                             sentence aspect sentiment
# 0  My father(an ex pilot and a doctor) had spotte...  pilot  negative
# 1417 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 1418 out of 92862
#                                             sentence       aspect sentiment
# 0  Was walking my dog late Christmas eve looking ...  helicopters  positive
# 1419 out of 92862
#                                             sentence        aspect sentiment
# 0  [" 'Bright white lights (one at the time) swit...  white lights  negative
# 1  All atitudes above 10", '000 feet  all directi...  white lights  positive
# 2  Their appearances are different from conventio...        lights  negative
# 3      The lights are frequently switched on or off.        lights  negative
# 4  Their speeds are that of a normal jet aircraft...  jet aircraft  negative
# 5  Their speeds are that of a normal jet aircraft...           air  negative
# 1420 out of 92862
#                                             sentence   aspect sentiment
# 0  [" 'Bright red star at about 30 degrees above ...  service  positive
# 1421 out of 92862
#                                             sentence         aspect sentiment
# 0  He described it's movement as a fish swimming ...  fish swimming  negative
# 1422 out of 92862
#                                             sentence      aspect sentiment
# 0  [' "Red Pulsating Light Seen in Boise on Chris...     hot tub  positive
# 1  It pulsated and moved very slowly', ' and then...       noise  negative
# 2  We joked that it was Rudulph the Reindeer's no...  Reindeer's  negative
# 1423 out of 92862
#                                             sentence  aspect sentiment
# 0  [" '6 fireballs ascended in formation and vani...  lights  negative
# 1  [" '6 fireballs ascended in formation and vani...  strobe  negative
# 1424 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Lights over Gaithersburg", ' MDSaw 5-7 ora...  lights  positive
# 1425 out of 92862
#                                             sentence         aspect sentiment
# 0  [" 'Glowing orange lights floating in the sky ...         lights  negative
# 1  [" 'Glowing orange lights floating in the sky ...  orange lights  negative
# 2  There was another orange light circling the ot...         lights  negative
# 3  There was another orange light circling the ot...         lights  negative
# 1426 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "A long Bar like shaped craft with lights a...  lights  positive
# 1  Moving extremely oddly in the sky almost cloak...  lights  negative
# 2  Moving extremely oddly in the sky almost cloak...      ",  negative
# 1427 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'serpentine UFO over Port Charlotte", ' FL ...  ...  negative
# 1  The object was "outlined" in blue and violet l...  ...  positive
# 2  As it was traveling just above tree level and ...  ...  positive
#
# [3 rows x 3 columns]
# 1428 out of 92862
#                                             sentence       aspect sentiment
# 0  [" '3 glowing orange orbs over the PA Turnpike...  orange orbs  positive
# 1  [" '3 glowing orange orbs over the PA Turnpike...  orange orbs  positive
# 1429 out of 92862
#                                             sentence      aspect sentiment
# 0  [" 'Red-Orange Silent Bright Light near Hammon...  Red-Orange  positive
# 1  There weren\\'t any strobes", ' or the standar...      lights  positive
# 1430 out of 92862
#                                             sentence  aspect sentiment
# 0  V Shaped light formation 4 lights on each side...  lights  negative
# 1  V Shaped light formation 4 lights on each side...  lights  positive
# 2  LIghts were VERY bright white and they pulsate...   white  negative
# 1431 out of 92862
# ...
# 0  [' "Five points of light', ' bit brighter than...  ' "Five  negative
# 2249 out of 92862
#                                             sentence         aspect sentiment
# 0  [" 'It was a conical flare at very high speed(...  conical flare  positive
# 1  [" 'It was a conical flare at very high speed(...          bread  negative
# 2  One most remarkable thing about the object was...          flare  negative
# 2250 out of 92862
#                                             sentence      aspect sentiment
# 0  My husband and I look and at first we think it...  helicopter  negative
# 2251 out of 92862
#                                             sentence         aspect sentiment
# 0  [" '2 bright orange lights observed by 7 peopl...  orange lights  positive
# 2252 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 2253 out of 92862
# Error Detected arrays must all be same length
# 2254 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'green dot floating sudden accelerationGree...  ...  negative
#
# [1 rows x 3 columns]
# 2255 out of 92862
#                                             sentence          aspect sentiment
# 0  The object was stationary', ' when first obser...        aircraft  negative
# 1  As a trained', ' USAF', ' Intelligence Operati...            USAF  negative
# 2  As a trained', ' USAF', ' Intelligence Operati...  Operations NCO  negative
# 3  I am', ' also', ' a student pilot and have wor...           pilot  negative
# 4  I am', ' also', ' a student pilot and have wor...        aircraft  negative
# 2256 out of 92862
#                                             sentence         aspect sentiment
# 0  [" '5 to 7 orange lights seen floating low in ...         lights  negative
# 1  [" '5 to 7 orange lights seen floating low in ...         lights  negative
# 2  [" '5 to 7 orange lights seen floating low in ...  orange lights  negative
# 3  [" '5 to 7 orange lights seen floating low in ...          pilot  negative
# 4  [" '5 to 7 orange lights seen floating low in ...         lights  negative
# 2257 out of 92862
#                                             sentence  aspect sentiment
# 0  There were no flashing lights on the object an...  lights  negative
# 2258 out of 92862
#                                             sentence  aspect sentiment
# 0  1915 hrs (7:15pm PST)', ' I was walking my kid...  Clovis  positive
# 2259 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 2260 out of 92862
# Error Detected arrays must all be same length
# 2261 out of 92862
#                                             sentence         aspect sentiment
# 0  [' what a strange colored light', ' considerin...         lights  negative
# 1  [' what a strange colored light', ' considerin...         planes  negative
# 2  The color was off as well', ' and the fact tha...  signal lights  negative
# 2262 out of 92862
#                                             sentence       aspect sentiment
# 0  [' "Me and my fiancee were out side taking dow...  decorations  negative
# 1  I watched for bout 30 -seconds to 1min then I ...    eletrical  negative
# 2  she told me the one we just seen while taking ...        noise  negative
# 2263 out of 92862
#                                             sentence          aspect sentiment
# 0  At first I thought I was seeing one of the loc...  Goodyear blimp  negative
# 1  I watch the jets come in every day at LAX & Lo...            jets  negative
# 2  No flat or curved surfaces were obvious.After ...        Aircraft  negative
# 2264 out of 92862
#                                             sentence aspect sentiment
# 0  Northwest over Hudson River", ' Albany', ' NYL...  pilot  negative
# 2265 out of 92862
#                                             sentence       aspect sentiment
# 0  [' "Firework type of formation hovering south ...  view mirror  positive
# 1  [' "Firework type of formation hovering south ...       lights  negative
# 2  It seems too low for any government aircraft t...     aircraft  negative
# 2266 out of 92862
#                                             sentence          aspect sentiment
# 0  [" 'I was reading about the recent increase in...   orange lights  negative
# 1  My forts sighting was reported to mufon and th...  forts sighting  positive
# 2  So I run upstairs and get my aunt and my cousi...    white lights  negative
# 3  I\\'m sure it\\'s not to much trouble to turn ...          Cessna  negative
# 4  I\\'m sure it\\'s not to much trouble to turn ...          planes  negative
# 5  It was almost literally scraping the hill tops...          lights  negative
# 6  It was almost literally scraping the hill tops...           music  negative
# 2267 out of 92862
#                                             sentence  aspect sentiment
# 0  lights that dispersedIt was Halloween and we w...  lights  negative
# 2268 out of 92862
#                                             sentence     aspect sentiment
# 0  At about 11:45 I was walking back to meet up w...       jets  negative
# 1  At about 11:45 I was walking back to meet up w...   aircraft  negative
# 2  Almost a minute of me (and now about 15 or so ...  aircrafts  negative
# 3  It was going so fast', ' almost looked like a ...     missle  negative
# 4  It was going so fast', ' almost looked like a ...        air  negative
# 5  My first guess is that it has something to do ...   AIRCRAFT  negative
# 6  http://www.youtube.com/watch?v=woCXh2kaw78&lis...   aircraft  negative
# 2269 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Traveling southwest", ' triangular dim lit...  lights  positive
# 1  [" 'Traveling southwest", ' triangular dim lit...     dog  positive
# 2270 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 2271 out of 92862
#                                             sentence  ... sentiment
# 0  [' "10/30/2011   21:00 Ronkonkoma  NY bright r...  ...  positive
# 1  [' "10/30/2011   21:00 Ronkonkoma  NY bright r...  ...  positive
#
# [2 rows x 3 columns]
# 2272 out of 92862
#                                             sentence  ... sentiment
# 0  [' "10/30/2011   21:00 Ronkonkoma  NY bright r...  ...  positive
# 1  [' "10/30/2011   21:00 Ronkonkoma  NY bright r...  ...  positive
#
# [2 rows x 3 columns]
# 2273 out of 92862
#                                             sentence aspect sentiment
# 0  I saw a bright white bluish light smaller than...   mars  negative
# 2274 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 2275 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 2276 out of 92862
#                                             sentence  aspect sentiment
# 0  These were perfect rounded ember glowing light...  lights  positive
# 2277 out of 92862
#                                             sentence      aspect sentiment
# 0  [" 'Huge white circular object with flashing l...  red lights  positive
# 1  The entire object was glowing white", ' incred...  red lights  negative
# 2278 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Hovering white light seen in Sydney", '  A...  planes  negative
# 1  (Not many planes were flying in Sydney at the ...  planes  negative
# 2279 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Tear Drop UFO observed for almost one hour...  ...  positive
# 1  Rookie mistake', ' but during one part of the ...  ...  positive
#
# [2 rows x 3 columns]
# 2280 out of 92862
#                                             sentence        aspect sentiment
# 0  As i faced south  east from my balcony on the ...          jets  negative
# 1  I think  it would fade when other aircraft cam...      aircraft  negative
# 2  No jet or earthly aircraft I've ever seen can ...      aircraft  negative
# 3  We couldn't have been the  only ones  with all...  eastern-city  positive
# 2281 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 2282 out of 92862
#                                             sentence         aspect sentiment
# 0  [" '5 Orange balls of light in triagle formati...  orange lights  negative
# 2283 out of 92862
#                                             sentence aspect sentiment
# 0  [" 'Accelerating lightOn October 30", ' 2011 a...    air  negative
# 2284 out of 92862
#                                             sentence  ... sentiment
# 0  [" '9 lighting flying objects in Kharkiv (Ukra...  ...  positive
#
# [1 rows x 3 columns]
# 2285 out of 92862
#                                             sentence        aspect sentiment
# 0  [" 'Glowing spheres over North Little Rock", '...    back patio  positive
# 1  The \\'flames\\' seemd to subside", ' leaving ...  \\'flames\\'  negative
# 2  There  were about six of them', ' and they wer...          line  negative
# 2286 out of 92862
# Empty DataFrame
# Columns: [sentence, aspect, sentiment]
# Index: []
# 2287 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Parade of mysterious Lights traveling acro...  lights  positive
# 2288 out of 92862
#                                             sentence      aspect sentiment
# 0  [" 'lights werent in a specific order though s...  [" 'lights  negative
# 1           lights were orangish red and on briefly.      lights  negative
# 2289 out of 92862
#                                             sentence        aspect sentiment
# 0  [" 'fireballi was having a smoke outside on th...  " 'fireballi  negative
# 2290 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Unidentified Green flashing Light During B...  lights  negative
# 2291 out of 92862
#                                             sentence      aspect sentiment
# 0  [" '3 red lights in rockford NOT planes!!!I wa...  red lights  negative
# 1  I was like at kmart area and seen 3 red lights...  red lights  negative
# 2  I was like they are not planes they are too cl...      planes  negative
# 2292 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'Bright blue and green lights while large s...  ...  positive
# 1  [" 'Bright blue and green lights while large s...  ...  positive
# 2  [" 'Bright blue and green lights while large s...  ...  positive
#
# [3 rows x 3 columns]
# 2293 out of 92862
#                                             sentence     aspect sentiment
# 0  We thought Maybe they were justa couple navy j...  navy jets  negative
# 2294 out of 92862
#                                             sentence           aspect sentiment
# 0  [" 'Orange lights traveling across the night s...   'Orange lights  negative
# 1  [" 'Orange lights traveling across the night s...           lights  negative
# 2  [" 'Orange lights traveling across the night s...           lights  negative
# 3  [" 'Orange lights traveling across the night s...  seperate lights  positive
# 2295 out of 92862
#                                             sentence  ... sentiment
# 0  [" 'My husband and I were sitting in our hot t...  ...  positive
# 1  I told my husband', ' âI think I just saw a ...  ...  negative
#
# [2 rows x 3 columns]
# 2296 out of 92862
#         sentence aspect sentiment
# 0  [' only land.     ['  negative
# 2297 out of 92862
#                                             sentence       aspect sentiment
# 0  At first I thought some helicopters were proba...  helicopters  negative
# 1  As I was looking at one of the red lights the ...         area  positive
# 2  As I was looking at one of the red lights the ...   red lights  positive
# 3  But all the red lights there on the hospital a...   red lights  negative
# 2298 out of 92862
#                                             sentence  aspect sentiment
# 0  [" 'Cluster of red lights in the Churubusco sk...  lights  negative
# 2299 out of 92862
#                                             sentence  ... sentiment
# 0  This is my story.On Halloween night', ' Octobe...  ...  positive
# 1  The lights appeared to be following the Susque...  ...  negative
# 2  We pulled over onto the shoulder and watched a...  ...  negative
# 3  The time was approximately 20:00 to 21:00 hour...  ...  positive
# 4  The time was approximately 20:00 to 21:00 hour...  ...  negative
#
# [5 rows x 3 columns]
# 2300 out of 92862
#                                             sentence     aspect sentiment
# 0  We both looked out at the stars as the night s...  night sky  negative
# 1  The lights on the axis were solid white and di...     lights  negative
# 2  This lasted for about 10 seconds and the objec...     lights  negative
# 2301 out of 92862
#                                             sentence      aspect sentiment
# 0  After the moon set and was below the horizon',...  Binocluars  negative
# 2302 out of 92862
#                                             sentence         aspect sentiment
# 0  [" 'Very bright orange sphere  turns to 2 sphe...  orange sphere  positive
# 1  I have seen these exact type and color of ligh...   orange balls  positive
# 2303 out of 92862
#                                             sentence        aspect sentiment
# 0  [" 'Green sphere viewed between the downs and ...  Green sphere  positive
# 1  [" 'Green sphere viewed between the downs and ...   green light  positive
# 2304 out of 92862
#                                             sentence         aspect sentiment
# 0  [" 'black circle object going through the clou...  army depot.']  positive
# 2305 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "My mother and father called my boyfriend a...    deck  positive
# 1  I started to go through my pictures at first i...  saucer  negative
# 2306 out of 92862
#                                             sentence        aspect sentiment
# 0  [" 'redish orange lites spinning and dancing l...  orange lites  positive
# 2307 out of 92862
#                                             sentence     aspect sentiment
# 0  darted across sky to form triangleI am Active ...  Air Force  negative
# 1  After staying stationary for maybe a minute ea...  Air Force  negative
# 2  After staying stationary for maybe a minute ea...   aircraft  negative
# 3  After staying stationary for maybe a minute ea...   missions  negative
# 4  Also', ' the lights were far too high in the s...     lights  negative
# 5  Also', ' the lights were far too high in the s...   aircraft  negative
# 2308 out of 92862
#                                             sentence   aspect sentiment
# 0  The Chinook ascended and ended up flying over ...  Chinook  negative
# 2309 out of 92862
#                                             sentence      aspect sentiment
# 0  [' "3 objects', ' yellow cylinder shape with a...   La crosse  positive
# 1  It had a glowing yellow cylinder type body but...  dorsal fin  negative
# 2310 out of 92862
#                                             sentence  ... sentiment
# 0  I looked up to the southern horizon and observ...  ...  negative
# 1  They moved slowly like you would expect to see...  ...  negative
# 2  The other 2 lights appeared to change position...  ...  negative
# 3  While there was light cloud cover', ' the clou...  ...  negative
# 4  We both questioned aloud whether they could be...  ...  negative
# 5  Conditions: 40âF Light cloud', ' no breeze. ...  ...  negative
#
# [6 rows x 3 columns]
# 2311 out of 92862
#                                             sentence aspect sentiment
# 0  [" 'Jet tailing a completely blacked out silen...   'Jet  negative
# 1  I could only hear the jet and did not hear any...  noise  negative
# 2312 out of 92862
#                                             sentence       aspect sentiment
# 0  I noticed it because I did not see any blinkin...  blue lights  negative
# 1  I noticed it because I did not see any blinkin...     aircraft  negative
# 2  2.  These lights seemed to have just disappeared.       lights  negative
# 2313 out of 92862
#                                             sentence  aspect sentiment
# 0  [' "Three large lights in the water of Santa M...  lights  negative
# 1  Only one of my friends said he saw a very fain...  lights  negative
# 2  I immeaditly told my family and they all made ...  lights  negative
# 2314 out of 92862
